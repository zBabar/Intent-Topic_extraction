# %%
from utils import Dataset, Preprocessing
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import gensim
from gensim import corpora
from wordcloud import WordCloud
import matplotlib.colors as mcolors
from nltk.corpus import stopwords

dutch_stop_words = stopwords.words('dutch')

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/zaheerbabar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_obj = Dataset() 

# get labelled data
train_df = data_obj.get_labelled_data()
process_obj = Preprocessing()

# preprocessing includes, text cleaning and label encoding
cleaned_train_df = process_obj.get_preprocessd_data(train_df, text_column="phrase")

# we need tokenized docs for GSDMM
tokenized_train_docs = process_obj.get_tokenized(cleaned_train_df)

train_vocab = set(x for doc in tokenized_train_docs for x in doc)

print(tokenized_train_docs)
# get labelled data
test_df = data_obj.get_unlabelled_data()
process_obj = Preprocessing()

cleaned_test_df = process_obj.get_preprocessd_data(test_df, text_column="user_msg", has_labels = False)

# we need tokenized docs for GSDMM
tokenized_test_docs = process_obj.get_tokenized(cleaned_test_df)

test_vocab = set(x for doc in tokenized_test_docs for x in doc)
# Out:
# [['iphone'], ['iphone', 'beschikbaar'], ['komen', 'iphone'], ['samsung', 'verkopen'], ['google', 'pixel'], ['iphone', 'xs', 'beschikbaar'], ['toestel', 'assortiment'], ['iphone', 'beschikbaar'], ['iphone', 'beschikbaar'], ['telefoon', 'aanbieden'], ['iphone', 'bestellen'], ['verkoop', 'samsung', 'note'], ['iphone', 'plus', 'beschikbaar'], ['verkopen', 'samsung', 'galaxy', 's20'], ['iphone', 'bestellen'], ['telefoon', 'bieden'], ['telefoon', 'beschikbaar'], ['verkopen', 'iphone'], ['iphone', 'beschikbaarheid'], ['verkoop', 'nieuw', 'toestel'], ['samsung', 'galaxy', 'amsung', 's20', 'assortiment'], ['toestel', 'beschikbaar'], ['samsung', 's20', 'beschikbaar'], ['iphone', 'beschikbaar'], ['toestel'], ['nieuw', 'telefoon', 'beschikbaar'], ['iphone', 'mini', 'beschikbaar'], ['iphone', 'verkopen'], ['beschikbaarheid', 'toestel'], ['beschikbaarheid', 'iphone', 'se'], ['nieuw', 'pixel', 'koop'], ['iphone', 'se', 'beschikbaar'], ['iphone', 'xs', 'beschikbaar'], ['iphonexs', 'beschikbaar'], ['verkopen', 'julie', 'iphone', 'x'], ['iphone', 'zilver', 'beschikbaar'], ['iphone', 'blauw'], ['toestel', 'verkrijgbaar'], ['komen', 'iphone'], ['telefoon', 'aanbieden', 'tmobile'], ['iphone', 'x', 'beschikbaar'], ['iphone', 'assortiment'], ['nieuw', 'samsung'], ['verkopen', 'Motorola'], ['winkel', 'iphone', 'kopen'], ['zwart', 'samsung'], ['samsung', 'verschillend', 'kleur'], ['iphone', 'beschikbaar'], ['beschikbaarheid', 'iphone', 'xs'], ['iphone', 'xs', 'max', 'beschikbaar'], ['telefoon', 'assortiment'], ['aanbod', 'toestel', 'weten'], ['verkopen', 'iphone', 'xs', 'max'], ['oppo', 'bruin', 'beschikbaar'], ['pixel'], ['huawei', 'p40', 'lite'], ['beschikbaarheid', 'iphone', 'pro'], ['iphone', 'pro', 'max', 'beschikbaar'], ['iphone', 'pro', 'max'], ['samsung', 's9', 'beschikbaar'], ['iphone', 'pro', 'max', 'beschikbaar'], ['abonnement', 'iphone', 'plus'], ['telefoon', 'beschikbaarheid'], ['toestel', 'bieden'], ['nokia', 'bestellen'], ['release', 'date', 'oppo', 'reno5'], ['toestel', 'bieden', 'allemaal'], ['beschikbaarheid', 'toestel'], ['verkopen', 'iphone'], ['wit', 'iphone'], ['iphone', 'bestellen'], ['ipohone', 'pro', 'max', 't', 'mobile'], ['blauw', 'samsung'], ['verkopen', 'iphone', 'xs'], ['kleur', 'bieden', 'toestel'], ['bieden', 'samsung', 's20', 'fe'], ['kleur', 'samsung', 'krijgen'], ['google', 'pixel'], ['beschikbaarheid', 'iphone', 'xr'], ['oppo', 'telefoons'], ['verkopen', 'iphone', 'xs', 'max'], ['iphone', 'xr', 'gb', 'beschikbaar'], ['aanbod', 'telefoon', 'tmobile'], ['kleur', 'huawei'], ['komen', 'nieuw', 'iphone'], ['verkopen', 'iphone'], ['kleur', 'samsung'], ['aanbod', 'toestel'], ['google', 'pixel', 'bestellen'], ['iphone', 'beschikbaar'], ['iphone', 'pro', 'bestellen'], ['huawei', 'p30'], ['telefoon', 'bieden', 'Tmobile'], ['krijgen', 'iphone'], ['verkopen', 'iphone', 'pro', 'max'], ['telefoon', 'verkopen'], ['kunnen', 'iphone', 'bestellen'], ['verkoop', 'samsung', 'note'], ['verkopen', 'telefoon'], ['beschikbaarheid', 'telefoon'], ['verkopen', 'nieuw', 'iphone'], ['iphone', 'bestellen'], ['telefoon', 'allemaal', 'assortiment'], ['kind', 'simkaart'], ['kinder', 'abonnemenen'], ['kind', 'abonnemenen', 'erbij'], ['kind', 'abonnemenen'], ['kinder', 'abonnemenen'], ['sim', 'kind'], ['simonly', 'kind'], ['abonnemenen', 'kind'], ['nieuw', 'nummer', 'kind'], ['goedkoop', 'simkaart', 'kind'], ['abonnemenen', 'speciaal', 'kind'], ['abonnemenen', 'kind'], ['kinderabonnemenat'], ['tmobile', 'kind'], ['contract', 'kind'], ['simkaart', 'kind'], ['kinderpakket', 'werken'], ['informatie', 'kindsbundel'], ['kind', 'account', 'aanmaken'], ['prepaidkaart', 'kind'], ['kids', 'only', 'bundel'], ['kind'], ['sim', 'only', 'kind'], ['sim', 'kind'], ['prepaid', 'simcard', 'kind'], ['Kinderpakket'], ['abonnemenen', 'dochter'], ['sim', 'only', 'kind'], ['abonnemenen', 'kind'], ['abonnemenen', 'kind'], ['kind', 'simkaart'], ['kinderabonnemenen'], ['Mobiel', 'kind'], ['simkaart', 'kind'], ['sim', 'only', 'kind'], ['abonnemenen', 'kind'], ['kind', 'abonne ...

# %% [markdown]
# #### GSDMM

# %%
from gsdmm import MovieGroupProcess

# %%
# Initialize and fit GSDMM model on labeled docs to check how it works as compared to the previous annotations. Let's start a lower number let's say 8 or 15 clusters

mgp = MovieGroupProcess(K=14, alpha=0.1, beta=0.1, n_iters=30)
y = mgp.fit(tokenized_train_docs, vocab_size=len(train_vocab))
# Out:
# In stage 0: transferred 1319 clusters with 14 clusters populated
# In stage 1: transferred 882 clusters with 14 clusters populated
# In stage 2: transferred 602 clusters with 14 clusters populated
# In stage 3: transferred 438 clusters with 14 clusters populated
# In stage 4: transferred 405 clusters with 14 clusters populated
# In stage 5: transferred 377 clusters with 14 clusters populated
# In stage 6: transferred 355 clusters with 14 clusters populated
# In stage 7: transferred 314 clusters with 14 clusters populated
# In stage 8: transferred 301 clusters with 14 clusters populated
# In stage 9: transferred 312 clusters with 14 clusters populated
# In stage 10: transferred 292 clusters with 14 clusters populated
# In stage 11: transferred 275 clusters with 14 clusters populated
# In stage 12: transferred 273 clusters with 14 clusters populated
# In stage 13: transferred 276 clusters with 14 clusters populated
# In stage 14: transferred 290 clusters with 14 clusters populated
# In stage 15: transferred 262 clusters with 14 clusters populated
# In stage 16: transferred 259 clusters with 14 clusters populated
# In stage 17: transferred 266 clusters with 14 clusters populated
# In stage 18: transferred 248 clusters with 14 clusters populated
# In stage 19: transferred 265 clusters with 14 clusters populated
# In stage 20: transferred 274 clusters with 14 clusters populated
# In stage 21: transferred 256 clusters with 14 clusters populated
# In stage 22: transferred 234 clusters with 14 clusters populated
# In stage 23: transferred 256 clusters with 14 clusters populated
# In stage 24: transferred 270 clusters with 14 clusters populated
# In stage 25: transferred 278 clusters with 14 clusters populated
# In stage 26: transferred 260 clusters with 14 clusters populated
# In stage 27: transferred 270 clusters with 14 clusters populated
# In stage 28: transferred 273 clusters with 13 clusters populated
# In stage 29: transferred 269 clusters with 13 clusters populated

# %%
doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic: {}'.format(doc_count))


print('Number of topics: {}'.format(len(np.unique(y))))
# Out:
# Number of documents per topic: [134 226  36  92  40 206  80 132 100 130 171  83  95   0]
# Number of topics: 13

# %%
top_index = doc_count.argsort()[-10:][::-1]
for i, topic_num in enumerate(top_index):
    print('\nTopic {}:'.format(i))
    for word in mgp.cluster_word_distribution[topic_num]:
        print(word)
# Out:
# Topic 0:
# telefoon
# abonnemenen
# g
# Mobiel
# abonnement
# maandelijks
# opzeggen
# opzegbaar
# verlagen
# veranderen
# contract
# aanpassen
# verlengen
# vernieuw
# huidig
# ready
# abbo
# abbonoment
# upgraden
# datum
# kunnen
# abbonement
# wijzig
# nieuw
# staan
# unlimited
# zitten
# opzegg
# sim
# only
# verlenging
# tussentijds
# verlopen
# maand
# dochter
# kinder
# databundel
# straks
# lopen
# abo
# toestelbetaling
# data
# willen
# aanpass
# downgrad
# samsung
# afbetalen
# aankoopsbewijs
# toevoeg
# nodig
# toegang
# mn
# krijgen
# service
# simonly
# thuis
# contractduur
# zeggen
# abonement
# zoeken
# opzegbaa
# doorlopen
# abonememt
# eenmalig
# mobiel
# zakelijk
# tv
# abonnoment
# internet
# tijdelijk
# besteling
# zojuist
# bestlen
# Go
# voortijdig
# hoog
# verhogen
# ongedaan
# maken
# wijzigen
# internetsnelheid
# zaterdag
# laten
# upgrade
# factuurmailing
# aflopen
# renew
# optie
# vernieuwen
# hulp
#
# Topic 1:
# heel
# bellen
# Mobiel
# internet
# langzaam
# g
# traag
# verbinding
# thuis
# werken
# echt
# goed
# telefoon
# netwerk
# gaan
# snelheid
# tmobile
# informatie
# internetverbinding
# moballen
# last
# onbeperken
# Location
# snel
# info
# weten
# blijven
# mobiel
# factuur
# abonnement
# abonnemenen
# slecht
# mobiel_telefoonnummer
# kindsbundel
# opeens
# all
# periode
# downloadsnelheid
# week
# stabiel
# Verbindingg
# reageren
# oorzaak
# bijzonder
# sloom
# laag
# enorm
# soms
# interneten
# lopen
# lijken
# teruggaan
# mega
# mobile
# speed
# hoezo
# streep
# so
# zwak
# haperen
# amersfoort
# vertragen
# bereikbaarheid
# vreselijk
# zien
# werk
# aangemeld
# storing
# resetten
# niks
# vinden
# kosten
# houden
# vertel
# verbruiken
# mb
# buitenland
# extra
# pakket
# levertijd
# contact
# wifi
# installatie
# aanschaf
# modem
# voorgevel
# passen
# afslutien
# interresseren
# mbit
# Factuurmail
# verlengen
# kort
# Betaal
# bestelen
#
# Topic 2:
# toestel
# aflossen
# krediet
# betalen
# afkopen
# inloss
# toestelkrediet
# bijbetaling
# nieuw
# factuur
# abonnemenen
# willen
# telefoonkrediet
# terug
# afbetalen
# man
# tablet
# euro
# keer
# bkr
# opzeggen
# deel
# betaling
# kost
# tussentijds
# afbetelen
# bedrag
# credit
# telefoon
# lopen
# aankopen
# voldoen
# stopzett
# aanbod
# aflossing
# verhogen
# toestelkredit
# terugbetalen
# registratie
# Mobiel
# verkrijgbaar
# weten
# begin
# restant
# komen
# ipad
# aflos
# lening
# inlos
# aanvraag
# eenmalig
# vervroegen
# eraf
# mn
# betaoen
# Toestel
# opheffen
# afmeld
# opzegg
# inlossen
# krediettoestel
# beindigen
# Aflosnota
# rest
# deels
# toestelcredit
# abbonnement
# inkiezen
# termijnen
# openstaan
# bestellen
# kunnen
# contract
# afbetaling
# terrugbetaling
# betaal
# ideal
# nemen
# restantbedrag
# lease
# x
# ivm
# helft
# versneld
# snel
# onbereikbaar
# wijziging
# ophoig
# contractvernieuwing
# tmobile
# onjuist
# hoelang
# correct
#
# Topic 3:
# iphone
# toestel
# factuur
# bon
# aankoop
# opvragen
# bewijs
# Aankoopbon
# nodig
# aankoopbewijs
# kopie
# Aankoop
# aankoopsbon
# kwijt
# aankoopfactuur
# nieuw
# telefoon
# verkoop
# Kopie
# koop
# Mail
# mobiel
# downloaen
# beschikbaarheid
# mailen
# Mobiel
# laten
# krijgen
# vinden
# aanschaf
# aflosnota
# zien
# service
# xs
# assortiment
# bieden
# opbellen
# onmogelijk
# aflosbewijs
# terugbetaal
# s8
# Gsm
# abo
# afkoop
# Winkel
# prepaien
# zakelijk
# orgineel
# kassabon
# Samsung
# zoeken
# ontvangen
# telwfoon
# aankoopbon
# Aankoopnota
# eindrekening
# hypotheek
# aangeschaffen
# gekocht
# vorig
# fold
# telefoonstoring
# bundels
# verhog
# contractverlenging
# wijzig
# internet
# afgeschreveb
# prijs
# vraag
# startdatum
# plaatsvinden
# plaats
# abonnement
# nummer
# phonenr
# staat
# Afgeschreveb
# staan
# open
# minnverzkeering
# vaststaan
# overzicht
#
# Topic 4:
# via
# factuur
# per
# Mail
# mail
# Email
# krijgen
# email
# ontvangen
# ontvang
# stuur
# sturen
# hoog
# maand
# verzend
# betalen
# g
# kloppen
# aansluitkost
# datum
# abonnemenen
# euro
# Emailadres
# vandaag
# waneer
# mai
# komen
# telefoon
# digitaal
# mailen
# afgeschreven
# telefoontoestel
# aankoopfactuur
# opzeggen
# belminuten
# verhoog
# belbundelen
# mbs
# betaalverzoek
# e
# toemail
# pdf
# mailbox
# kunnen
# Will
# Factuur
# verlengoptie
# 1
# creditering
# zichtbaar
# vraag
# tablet
# Betaal
# corrigeren
# onverwacht
# factuuren
# date
# gisteren
# teveel
# tv
# aansluitingkosten
# toelicht
# factuurbedrag
# adres
# willen
# staan
#
# Topic 5:
# telefoon
# bereik
# huis
# internet
# slecht
# g
# dekking
# thuis
# week
# adres
# Mobiel
# bellen
# Location
# heel
# omgeving
# netwerkverbinding
# amper
# ontvangst
# verbinding
# helemaal
# netwerk
# bel
# goed
# echt
# snelheid
# Nederland
# werken
# laat
# tijd
# wifi
# dienst
# aanbieden
# kinderabonnemenat
# kinderpakket
# Kinderpakket
# paar
# thuisadre
# bereikbaar
# amstelveen
# huisadres
# signaal
# ontzettend
# tragen
# langaam
# contineu
# last
# oplossen
# vol
# traag
# langzaam
# moballen
# vrijwel
# wonen
# moment
# opbellen
# vreselijk
# Groningen
# laag
# kwaliteit
# vakantie
# afbetaling
# tablet
# afbetalen
# toestelcrediet
# Storing
# vinden
# bereiken
# maken
# server
# staan
# probleem
# geven
# krijgen
# zeggen
# vallen
# zien
# instaan
# uitgevallen
#
# Topic 6:
# tmobile
# sim
# kind
# simkaart
# abonnemenen
# contract
# only
# verlengen
# verleng
# simonly
# november
# optie
# Mobiel
# februari
# juni
# service
# september
# mogelijkheid
# verhog
# verlenging
# erbij
# goedkoop
# speciaal
# account
# aanmaken
# prepaidkaart
# prepaid
# simcard
# kinderabonnemenen
# nieuw
# abonnementen
# aankoopbewijsfactuur
# aankoopbewijs
# toestelfactuur
# Marokko
# blokkeur
# netwerk
# verbind
# toepassen
# verlagen
# aanpassen
# internet
# offert
# vinden
# go
# april
# december
# jaar
# offeren
# offerte
# kost
# eind
# periode
# melding
# mei
# automatisch
#
# Topic 7:
# betalen
# krijgen
# betaling
# ideal
# link
# factuur
# betaal
# rekening
# sturen
# via
# staan
# beta
# betaallink
# factur
# openstaan
# sms
# nota
# direct
# toestelkrediet
# bedrag
# Mail
# netwerkdekking
# overzicht
# Restbedrag
# S10
# plus
# Mobiel
# netwek
# bereikbaar
# internetsnelheid
# verhogen
# middels
# zoeken
# verzoek
# idealbetaallink
# achterstand
# betaalen
# betalingslink
# mn
# Mijnn
# open
# overma
# missen
# afsluiten
# kunnen
# imail
# willen
# ren
# betalingsregeling
# zien
# verkeerd
# abonnements
#
# Topic 8:
# internet
# abonnemenen
# aanpassen
# internetsnelheid
# verhogen
# bundel
# verlagen
# mb
# gb
# snelheid
# wisselen
# belminuot
# veranderen
# bundels
# aanpass
# belbundel
# belminut
# langzaam
# hoog
# mbs
# per
# maand
# bewijs
# pakket
# kids
# only
# zoon
# dekkingskaart
# toestelaflos
# toestelkrediet
# inkoop
# bereik
# aanpassing
# toevoegen
# bellen
# blijven
# nergens
# sim
# kaart
# huidig
# laag
# verhoging
# sms
# extra
# bunder
# vorig
# ophon
# tijdelijk
# vergroten
# ophogen
# aantal
# minuut
# laat
# factur
# Emailadres
# verlengen
# vernieuwing
# contractverlening
# klant
#
# Topic 9:
# iphone
# beschikbaar
# pro
# max
# beschikbaarheid
# factuur
# se
# bestellen
# plus
# verkopen
# x
# xr
# xs
# komen
# google
# pixel
# nieuw
# kopen
# t
# mobile
# toestel
# telefoon
# assortiment
# abonnement
# afbetaling
# dienst
# mini
# koop
# iphonexs
# julie
# zilver
# blauw
# winkel
# nokia
# wit
# ipohone
# gb
# krijgen
# kunnen
# snelheid
# laag
# wegvallend
# resteren
# betallen
# euro
# huidig
# nodig
# pakken
# netwerkinstelling
# service
# verwijderen
# bellimiet
# verlagen
# aanpassing
# toevoegen
# Permail
# uitstel
# verlebging

# %%
mgp = MovieGroupProcess(K=30, alpha=0.1, beta=0.1, n_iters=30)
y = mgp.fit(tokenized_test_docs, vocab_size=len(test_vocab))

doc_count = np.array(mgp.cluster_doc_count)
print('Number of documents per topic: {}'.format(doc_count))

top_index = doc_count.argsort()[-10:][::-1]
# Out:
# In stage 0: transferred 3527 clusters with 30 clusters populated
# In stage 1: transferred 2661 clusters with 30 clusters populated
# In stage 2: transferred 1865 clusters with 30 clusters populated
# In stage 3: transferred 1383 clusters with 30 clusters populated
# In stage 4: transferred 1156 clusters with 28 clusters populated
# In stage 5: transferred 997 clusters with 26 clusters populated
# In stage 6: transferred 941 clusters with 25 clusters populated
# In stage 7: transferred 892 clusters with 24 clusters populated
# In stage 8: transferred 876 clusters with 23 clusters populated
# In stage 9: transferred 866 clusters with 23 clusters populated
# In stage 10: transferred 817 clusters with 22 clusters populated
# In stage 11: transferred 831 clusters with 21 clusters populated
# In stage 12: transferred 816 clusters with 22 clusters populated
# In stage 13: transferred 798 clusters with 22 clusters populated
# In stage 14: transferred 780 clusters with 21 clusters populated
# In stage 15: transferred 747 clusters with 21 clusters populated
# In stage 16: transferred 739 clusters with 19 clusters populated
# In stage 17: transferred 741 clusters with 19 clusters populated
# In stage 18: transferred 769 clusters with 19 clusters populated
# In stage 19: transferred 757 clusters with 19 clusters populated
# In stage 20: transferred 722 clusters with 19 clusters populated
# In stage 21: transferred 731 clusters with 19 clusters populated
# In stage 22: transferred 764 clusters with 19 clusters populated
# In stage 23: transferred 760 clusters with 20 clusters populated
# In stage 24: transferred 727 clusters with 19 clusters populated
# In stage 25: transferred 700 clusters with 20 clusters populated
# In stage 26: transferred 716 clusters with 19 clusters populated
# In stage 27: transferred 717 clusters with 22 clusters populated
# In stage 28: transferred 764 clusters with 19 clusters populated
# In stage 29: transferred 778 clusters with 20 clusters populated
# Number of documents per topic: [483 312   0 173   0 224 197 173  29   2   0   0   7   0 339   0 179   6
#  213 629  18   0  11   0 140   0 112   0   8 536]

# %%
for i, topic_num in enumerate(top_index):
    print('\nTopic {}:'.format(i))
    for word in mgp.cluster_word_distribution[topic_num]:
        print(word)
# Out:
# Topic 0:
# g
# thuis
# locatie
# internet
# krijgen
# extra
# graag
# abonnement
# veranderen
# abonnemenen
# wijzig
# abbonement
# aanpassen
# Hallo
# activeren
# werken
# wifi
# buitenrouter
# toestel
# beschikbaar
# nieuw
# hoi
# weten
# verleng
# zien
# zetten
# bestellen
# vraag
# snel
# k
# router
#
#
# klacht
# installatie
# buitenunit
# goedemorgen
# zitten
# adres
# abo
# klantvoordeel
# tv
# vast
# zakelijk
# gebruiken
# instelling
#
# kosten
# Mobiel
# aansluiten
# mijn
# informatie
# telkens
# monteur
# unlimited
# kapot
# meenemen
# verhuizen
# gaan
# staan
# gmail
# afsluiten
# goedendag
# t
# mobile
# inzien
# bundel
# zet
# abbonnement
# abonement
# goed
# tussentijds
# nergens
# pakket
# gb
# overstappen
# televisie
# qr
# code
# contract
# geldig
# langzaam
# abonament
# maandelijks
# prijs
# lopen
# vragen
# onbeperken
# wijzegen
# toevoeg
# internetsnelheid
# goedemiddag
# omzetten
# kost
# wijziging
# data
# opbellen
# I
# doen
# helpen
# telefoon
# vallen
# betalen
# account
# laten
# abbo
# verbinden
# plus
# buitengebied
#
#
#
# mbs
# leeg
# morgen
# naam
# simkaart
# gran
# buitwn
# gaat
# binnenkomen
# maal
# wachtwoord
# verkeerd
# invoeren
# bedoelen
# Mijm
# terug
# berijk
# zenderpakket
# batterij
# vul
# vlan
# internetpakket
# beveiligingscode
# ip
# snelheid
# huidig
# american
# google
# pixel
# betaalsysteem
# knippren
# goedemorg
# buitenkabel
# lang
# ka
# scannen
# zojuist
# maandbasis
# selecteren
# goedenavond
# afvragen
# leasen
# ordernummer
# ophalen
# nee
# annuleren
# vergelenen
# extreem
# trage
# komen
# keer
# deezers
# verzamelen
# aanstaan
# bundels
# ee
# nvraag
#
# behoud
# klantkorting
# testen
#
#
# instel
# best
# status
# ondersteunen
# duren
# verhogen
# opzoek
# opzetten
# netwerk
# buitenantenne
# A.
# iphoen
# vinden
# sorry
# beheerder
# nemen
# lanzarote
# afspraak
# connect
# huis
# uitbreiden
# overzetten
# maildre
# dinsdag
# warn
# 4gvoor
# ookal
# factuurdatum
# scann
# mbaanvuller
# startbundel
# horen
# zakkelijk
# Atenne
# service
# actiever
# internetverbinding
# lijken
# erop
# houden
# standaard
# klant
# nummer
# toegang
# tog
# verblijf
# verhuizing
# zoeken
# beschikn
# momenteel
# huawei
# bemoeienis
# overheid
# eenmalig
# as
# à
# Duits
# kijken
# wanner
# airpods
# oud
# ipad
# acrtiveren
# dial-up
# mn
# opzegg
# overgaan
# kras
# bezorger
# plannen
# betaaldatum
# activ
# kieze
# hetzelfde
# hebgeen
# overeenkomst
# abonnent
# nar
# dagtegoed
# gister
# lte
# koppel
# familiepakket
# ijn
# overstapp
# bezorgdienst
# gebruikskost
# Go
# helaas
# verbinding
# buitenland
# hoelang
# voo
# rthuis
# paal
# why
# note
# ultra
# contact
# bedrijf
# aanvragen
# repareur
# eu
# pagina
# aa
# defect
# poorte
# open
# kop
# Bundels
# welkom
# rekening
# verandering
# plaas
# weizigen
# kunnen
# daarmee
# Wifi
# pakker
# lomp
# oneplus
# opzeggen
# geven
# foutmelding
# retourlabel
# combinatie
#
# Topic 1:
# abonnemenen
# per
# graag
# locatie
# mb
# ’s
# kopen
# hi
# extra
# krijgen
# bellen
# bundel
#
# lukken
# internet
#
#
# via
# eu
# keer
# tijdelijk
# mb's
# toevoegen
# €
# buitenland
# datum
# laag
# Hallo
# anfullen
# verhogen
# week
# data
# bijkopen
# zitten
#
# gb
# willen
# gebruiken
# mbs
# bevestigen
# onbeperken
# internetten
# gaan
# gratis
# zoon
# overzicht
# abonnement
# melden
# vebinding
# teveel
# snelheid
# vol
# ziggo
# verlagen
# koop
# staan
# maand
# goedemorgen
# uitbreiden
# snel
# vraag
# verde
# maandelijks
# ipv
# kost
# g
# aanschaffen
# gebruik
# hoeveel
# kosten
# will
# gelden
# ineens
# normaal
# service
# databundel
# vs
# nl
# maken
# inzien
# huidig
# internetpakket
# betalen
# i̇k
# abonament
# interneten
# navigatie
# minuut
# Europa
# land
# simkaart
# Mobiel
# werken
# hoi
# internetbundel
# mobiel
# geld
# verbruikken
# hoezo
# telefoonnummer
# dag
# topup
# benieuwd
# download
# upload
# internett
# telefoon
# abbonnement
# nee
# traag
# belen
# bel
# refurbished
# iphones
# regelmatig
# wijziging
# gig
# nodig
# factuur
# veranderen
# stoppen
# app
# tarief
# morgen
# etnische_groep
# smss
# kr
# hai
# tekening
# Storing
# gekochtvan
# missen
# 100extra
# stuurideal
# goedemorg
# maart/april
# behoud
# zone
# supertraag
# bestellen
# goeiedag
# bali
# bank
# demaandelijks
# abbo
# limiet
# i̇s
# gebeld
# maandbedrag
# klein
# nemen
# kosteloos
# Buiteland
# ideal
# koap
# playstore
# berich
# 80%
# kennen
# beltegoed
# oktober
# Lotte
# usa
# bijbetalen
# begrijpen
# goed
# druk
# krr
# abnomment
# wik
# aanmelding
# opa
# pauzeur
# volumen
# achterstand
# vriend
# inbegrepen
# I
# cloud
# Helle
# eenmalig
# ruim
# aantal
# rechter
# voicemail
# nr31
# tombile
# ongeluk
# kopen/halen
# tussentijds
# Face
# time
# vaar
# oplossen
# tekort
# nogmaals
# t
# abbonnenent
# nie
# regelen
# vergroten
# oplaen
# betalingsachterstand
# site
# mobile
# ophon
# verlengen
# woonplaats
# goedeavond
# block
# nogsteeds
# my
# openen
# ap
# hoi̇
# wi̇l
# afbetelen
# inzetten
# uitleg
# ci
# module
# lotte
# sms
# aankomen
# vrijdag
# snap
# vab
# p
# verwerken
# verdwijnen
# opdracht
# afdeling
# reclame
# aanvrag
# brengen
# samenvieg
# e-mailadres
# vriendelijk
# groet
# Mandy
# verschil
# ervan
# verhog
# belbundel
# einde
# aankopen
# betaal
# vandaag
# mbit/s
# ei
# hoog
# goedkoop
# wonten
# lijken
# erop
# heel
# geven
# kloppen
# zwiterland
# verdelen
# tel
#
#
# hiervoor
# pakket
# zichtbaar
# bevestiging
# deco
# prijs
# belachelijk
# stijgen
# bijgewerken
# telefoonabonnement
# bellen/sms
# adres
# mb/s
# instellen
# zeggen
# bevestig
# knop
# reageren
# dochter
# Europees
# glasvezel
#
# Topic 2:
# beschikbaar
# g
# bellen
# locatie
# krijgen
# netwerk
# mobile
# thuis
# laat
# slecht
# bereik
# internet
# traag
# telefoon
# buitenland
# hi
# service
# telefonisch
#
# langzaam
# zowel
# goedemorgen
# streep
# verbinding
# t-mobile
# staan
# tijd
# paar
# dag
# week
# heel
# moballen
# beeld
# huis
# erg
# ontzettend
# storing
# enorm
# mobiel
#
# goedemiddag
# goed
# Mobiel
# ontvangst
# hoi
# unlimited
#
#
# dekking
# probleem
# goeiedag
# super
# internetverbinding
# last
# ziekenhuis
# echt
#
#
# Hallo
# werken
# vraag
# helemaal
# sorry
# zeggen
# blijven
# lijken
# komen
# aangemeld
# melding
# wifi
# simkaart
# maken
# mn
# geven
# Netwerk
# aanmelden
# soms
# mb
# klacht
# gisteren
# extra
# opgestren
# langzam
# vallen
# snel
# mee
# opzeggen
# normaal
# abonnemenen
# via
# oplossen
# werk
# zitten
# abonnement
# verbinden
# ontvangen
# vandaag
# prima
# liggen
# nieuw
# hallo
# trage
# gaan
# bereiken
# tegoed
# geval
# chat
# dienst
# tv
# sloom
# datum
# worden
# telefoonnummer
# connectie
# sms
# contact
# momenteel
# nee
# info
# nauwelijks
# t
# moe
# goedemorg
# thuisabonnement
# vrijdag
# helpen
# keer
# abo
# netwerkverbinding
# kloppen
# automatisch
# zetten
# trag
# meerdere
# installatie
# thuiswerkplek
# Martinique
# overdag
# eu
# edge
# uitmaken
# langzamer
# oke
# hand
# telfoon
# vriendin
# bekend
# groet
# Suzanne
# 4g+
# download
# senlheid
# mblper
# sec
# wifipunt
# laten
# terugbellen
# us
# ochtend
# tenerife
# boek
# euro
# vw
# stop
# weten
# gewijzig
# julie
# bundel
# kopen
# a
#
#
#
# binnenshuis
# Apps
# niks
# ata
# verbinsing
# opbellen
# proberen
# antenne
# daardoor
# e-simkaart
# janken
# laan
# westerik
# ïnformeren
# terugverkoopformulier
# teleofon
# storen
# verminderde
# woensdag
# internationaal
# chauffeur
# laa
# klant
# kabel
# huawei
# modem
# batterijduur
# fatsoenlijk
# goedendag
# werkplek
# toegang
# mein
# gebr
# doit
# verlenging
# geactiveren
# allemaal
# mobilie
# t-mobiles
# alweer
# niemand
# jeet
# hoor
# bijvoegen
# moment
# roaming
# vreselijk
# turijn
# gister
# betaallink
# eerd
# ineens
# hellup
# zien
# data/5
# 4g/5
# veelssen
# internetsnelheid
# heletijd
# betaal
# moeilijk
# oplichter
# land
# continue
# lad
# versterker
# nodig
# amper
# ivm
# he
# doordat
# reageren
# vertellen
# buitenshuis
# klagen
# gebeld
# stellen
# opponement
# databundel
# alsnog
# raken
# signaal
# dagelijks
# onbeperkt
# afloggen
# Network
# selcht
# oplaen
# sim
# only
# aankomen
# mantelzorg
# verdorie
# geldig
# denken
# verkeerd
# systeem
# goedenavond
# plaats
# 2.4ghz
# mens
# horen
# verbindinh
# horloge
# se
# gps
# aanstaan
# centraal
# ps
# safari
# apps
# data
# gecontact
# hoogtuiten
# laast
# Lotte
# aanvull
# aangezeten
# dank
# wonen
# klunnen
# verschrikkelijk
# simcard
# wrken
# eenmaal
# zwak
# beantwoorden
# leeg
# scherm
# onlangs
# netwerken
# opeens
# installeren
# wrm
# .traag
# Kreta
# uitgevallen
# bekabelde
# bekabelen
# zaak
# hard
# regenen
# goeden
# avoid
# be
# beachikbaar
# vertel
# aanvullen
# lukken
# ïnstalleren
# ervaar
# iphone
# wennen
# telkens
# onderweg
# inclusief
# to
# heen
# imobieel
# aanwezig
# tv's
# uurt
# opgaan
# snap
# centrum
# opstarten
# toegeven
# pincode
# 100mb/sec
# instabiel
# sercice
# e
# waardelos
# familie
# vriend
# serivce
# I
#
# Topic 3:
# locatie
# vraag
# betalen
# telefoon
# laat
# factuur
# krijgen
# gaan
# zien
# graag
# abonnemenen
# maand
# Hallo
# hoog
# faktuur
# nieuw
# factur
# normaal
# abonnement
# hi
# hoi
# datum
# kloppen
# laa
# klpen
# hoogte
# weten
# afgeschreven
# vragen
#
# bekijken
# vinden
# goedemorgen
# denken
# fout
# staan
# maken
# bedrag
# reden
# euro
# verwachten
# plots
# stuk
#
#
# rekening
# september
# terug
# mee
# eu
# facatuur
# komen
# kosten
# berekenen
# afschrijving
# kost
# uitleg
# waarschijnlijk
# abbonement
# afspreken
# 2x
# mail
# betaal
# inzien
# duur
# €
# extra
# betreffen
# mobiel
# vandaag
# maandelijks
# afsluiten
# tm
# betaling
# stoppen
# voldoen
# bellen
# ipv
# nummer
# vorig
#
#
# account
# buitenland
# gebeld
# overgestapt
# goedendag
# ontvangen
# lukken
# vreemd
# 1
# goedemorg
# vodafoon
# missen
# verkeerd
# automatisch
# bestand
# compensatie
# bericht
# juli
# eenmalig
# via
# wijzigen
# klant
# mai
# overzicht
# contract
# jaar
# gratis
# inkijken
# korting
# bedragen
# overeen
# erg
# kunnen
# kopen
# afbetaling
# heylen
# brengen
# willen
# spañe
# sturen
# open
# netwerk
# tarief
# oud
# inlog
# info
# goedenavond
# telefoonnummer
# woord
# openstaandbedrag
# tekenen
#
# negatief
# office
# stopzetten
# Email
# geschiedenis
# i
# what
# bewijs
# erst
# genoeg
# technisch
# huistelegoon
# zitten
# gegeven
# opgehalen
# openstaat
# europ
# boeken
# nier
# zicht
# baar
# moment
# contact
# nosig
# verwacht
# verekenen
# kortingsbedrag
# 85eu
# nogwat
# maandkost
# doormail
# aanbieder
# all
# laag
# eigenlijk
# wijken
# rest
# blokkade
# schrijven
# midden
# nacht
# 03:00
# tevens
# kwartaal
# toestelcrediet
# afschrijven
# afschrijv
# Emailadres
# elkaar
# ativeren
# pagina
# goed
# middag
# ikwil
# uitleggen
# aub
# waarbij
# Europa
# toeslag
# noemen
# verwijderen
# wisselen
# unlimited
# blijken
# ho
# if
# idee
# daarover
# dank
# winkel
# termijnregeling
# dom
# sluipen
# 70e
# check
# plannen
# abbonnement
# Unlimeted
# activatiekosten
# samenvatting
# bestelnummer
# nemen
# geldig
# bijzonderheid
# recent
# crediteren
# waneer
# hzo
# nergens
# opzeggen
# liggen
# storten
# helaas
# nogmaals
# incasser
# overstapkosten
# instalatie
#
# Lotte
# cgl25209
# vallen
# aangegeven
# facature
# moesst
# beoordeling
# toet
# gister
# aangeven
# duren
# inloggen
# kijken
# verzend
# misgegaan
# onbeperken
# snap
# kaar
# meekijken
# download
# geven
# beschadigen
# correct
# 14.50euro/maand
# maat
# worden
# mailadres
# opzoek
# waarin
# toestel
# compensatiebedragen
# opvoeren
# hekocht
# terugbellen
# foutmelding
# maand:43,69
# januari
# afgetrokken
# volgen
# februari
# vermelden
# maart
# mobile
# geld
# antwoord
# hierop
# Groet
# Wim
# amijn
# 50%
# teveel
# afbetaald
# afsluit
# afgehalen
# hoveel
# waaneer
# uitbetaling
# zoeken
# ineens
# erbij
# buitenlands
# senioren
# instelling
# belminuten
# naam
# vijftien
# verhogen
# maandabonnement
# overgezet
# boekhouding
# laatste/eerst
# nota
# rabo
# afgehouden
# contactmoment
# llaat
# beeindigen
# inlogg
# begrijpen
# 33,-
# normaaan
# t-moobil
# stuuren
# schade
# vergoeding
# beteken
# beftreven
# huidig
# abonnementskost
# signal
# war
# abnormaal
# ondanks
# lotte
# factuurbedrag
# duidelijkheid
# abonnementbedrag
# installeren
# gesprek
# ?
# activatie
# qtaat
# benieuwd
# opbouw
# kopem
#
# Topic 4:
# factuur
# betalen
# telefoon
# graag
# ontvangen
# abonnemenen
# werken
# zien
# staan
# ideal
# link
# laat
# factur
# keer
# komen
#
#
# nieuw
# sturen
# krijgen
# willen
# email
# mail
# betaal
# openstaan
# bedrag
# euro
# afbetalen
# zodat
# gaan
# via
# Mobiel
# ideaal
# blokkeren
# hoi
# tv
# doen
# betaling
# mislukken
# achterstand
# maand
# automatisch
# stuur
# goeiemiddag
# rekening
# hi
# toesturen
# oud
# september
# kunnen
# regeling
#
# goedemorg
# e-mail
# blokade
# mee
# site
# volledig
# aub
# foutmelding
# betaallink
# blokkade
# deel
# augustus
# termijn
# verlopen
# e-mailadres
# terug
# verzoek
# beta
# deal
# alvast
# vactuur
# ideal-
# wachten
# incasso
# duren
# tp
# mailen
# goedenavond
# internet
# uur
# betalingsregeling
# bankrekening
# opheffen
# k
# oktober
# verbinding
# lotte
# ontvang
# afgeschreven
# abonnement
# fout
# sluiten
# tijd
# aankomen
# treffen
# kijken
# gooien
# dag
# simkaart
# normaal
# hoelang
# locatie
# telefoonnummer
# beschikbaar
# optie
# il
# slot
# order
# blijven
# onbetalen
# verhelpen
# zoekgeraakt
# e
# Mail
# stuuur
# will
# degeen
# aanschaf
# eind
# mandelijk
# allang
# notaris
# bewijs
# knop
# last
# internt
# lieg
# eruit
# bevestiging
# afgeboekt
# fatuur
# dubbel
# vn
# houlang
# t
# m
# informeren
# achterstallig
# internetten
# I
# oer
# zwaar
# bestelling
# gisteren
# misgegaan
# splitsen
# een
# november
# goed
# doorvoeren
# beetje
# vinden
# kopie
# facuur
# bewindvoerder
# vragen
# good
# morgen
# factuuroverzicht
# betlen
# betalings
# aanschaffen
# Hallo
# zaterdag
# zondag
# nix
# verwerken
# vertellen
# ite
# procedure
# heden
# terugbetalen
# tekstbericht
# abbo
# aanwezig
# Gene
# daarvoor
# rekeninf
# bullshit
# tmobile
# Dashboard
# lopen
# aansluiten
# 13.00u
# bet
# direct
# nodig
# middels
# juli
# i
# openstaand
# doorlink
# onderzoek
# formulier
# plannen
# datum
# overal
# opwaarderen
# bezig
# verlengen
# plaats
# stuuren
# gratis
# betaalregeling
# Notificatie
# usa
# ivkm
# verklaring
# x
# klantnaam
# bestand
# spelen
# ideeel
# meteen
#
#
# mytmobile
# box
# blokaden
# chekken
# saldo
# vanmorgen
# betalingsachterstand
# bun
# aanpass
# internetsnelheid
# aanpassen
# wer
# werkdag
#
# iemeel
#
#
#
# retourlabel
# nogsteeds
# nogmaals
# werk
# daarmee
# aangevraagen
# loten
# totaalbedrag
# aansluiting
# gisteravond
# vd
# kiezen
# waarop
# linkje
# hoeveel
# 2verschillen
# facturen,13,50
# per
# hallo
# ieder
# binnenkrijg
# boxen
# opwaardering
# constant
# verkoop
# laptop
# nergens
# storneeren
# vandaag
# bestellen
# links
# afbetaald
# halen
# worden
#
# Topic 5:
# graag
# bedrag
# gedeelte
# betalen
# afbetalen
# telefoon
# krediet
# aflossen
# keer
# factuur
# hoi
# toestel
#
#
# afkopen
# nieuw
# termijn
# afbetelen
# hoeveel
# volledig
# verkopen
# terugbetalen
# hallo
# kosten
# Restbedrag
# beetje
# resteren
# openstaan
# willen
# toestelkrediet
# sony
# iphone
# doen
# per
# Hallo
# inlossen
# weten
# verhogen
# gedeeltelijk
# bon
# afbetaling
# betaling
# mn
# bkr
# registratie
# vragen
# one
# plus
# lening
# schuld
# goedemiddag
# laat
# bieden
# oneplus
# hi
# vraag
# goedemorgen
# aflosnota
# nee
# abonnemenen
# snel
# deel
# Mobiel
# terug
# mobiel
# betaalverzoek
# eenmalig
# hoeven
# erbinding
#
#
# €
# g5
# creditcard
# winkel
# toetstelkrediet
# Edge
# vandaag
# versnelen
# bekijken
# boeteloos
# opslag
# kredieten
# mbs
# perdag
# toestelkridieten
# will
# bestaan
# spañe
# acpeteren
# julie
# toestelkost
# aanbetaling
# m
# ’n
# via
# beschikbaaris
# gebruiksvrienedlijk
# senior
# dement
# gespreid
# overstap
# bedoelen
# mandelijks
# ok
# direct
# geheel
# toestelkriediet
# toetselkrediet
# Godver
# extra
# customer
# crediet
# x
# regeling
# 1x
# bijbetalen
# opzoek
# eigendomsbewijs
# waarop
# info
# xperia
# zeggen
# abbonoment
# abonnement
# verlopen
# eigenlijk
# vivo
# onlangs
# verkrijgen
# Galaxy
# Flip
# z4
# divers
# mankement
# betalingstermijn
# overig
# telefoonkost
# restbedrag
# jaar
# charlotte
# kwijt
# raken
# aflossing
# bewijs
# overal
# tel
# rest
# open
# staan
# favtiir
# vinden
# app
# termijnbetaling
# maandelijk
# contracts
# afnemen
# telefoons
# kopen
# helemaal
# stopzett
# huidig
# aannemen
# nodig
# restant
# hoofdaansluiting
# subway
# surfer
# 1play
# nokia
# toest
# adviseren
# huawai
#
# Topic 6:
# factuur
# per
# bellen
# internet
# g
# thuis
# abonnemenen
# datum
# abonnement
# wijziging
# gb
# bundel
# graag
# goedemorgen
# unlimited
# upgraden
# entertainment
# gebruik
# zien
# vraag
# afsluiten
# maken
# dag
# krijgen
# nieuw
# maand
# hi
# komen
# data
# zojuist
# wijzigen
# aanpassen
# euro
# extra
# verbruik
# tablet
# natuurlijk
# vullen
# Hallo
# betalen
# gaan
# nodig
# ’s
# onbeperken
# mb
# opeens
# verlengen
# direct
# wijzig
# vorig
# huidig
# contract
# t
# volgen
# telefoon
# nemen
# upgrade
# mob
# aanbod
# ontvang
# downgrade
#
# m
# werkend
# terug
# betaal
# goedemiddag
# tele2
# paar
# gratis
# netwerk
# contact
# opzeggen
# zitten
# g.
# staan
# website
# veranderen
# lotten
# blijven
# vrijdag
# sim
# korting
# k
# week
# provider
# €
# vakantie
# toegang
# ivm
# erbij
# vrouw
# hoi
# gebeld
# cadeau
# monteur
# account
# verhogen
# niks
# lopen
# telefonisch
# only
# toestel
# straatadre
# toevoegen
# rekening
# doen
# lezen
# laag
# loten
# hoeveel
# willen
# kost
# vast
# opmerking
# naam
# laat
# maandelijks
# afvragen
# gegeven
# abbonoment
# kosten
# uitleggen
# goedkoper
# ineens
# tijd
# plaats
# nummer
# bekendstaan
# collega
# spreken
# ’n
# avond
# aanvullen
# jaar
# service
# overgestapt
# dagtegoed
# hoezo
# medewerker
# netflix
# videoland
# bestelling
# aansluiting
# daardoor
# houden
# laatst
# inzetten
# Standaard
# tegenwoordig
# v
# facatuur
# datalimit
# dochter
# ga
# bestellen
# cancelen
# stelen
# bereikbaar
# fout
# 1x
# abommmen
# belminut
# hetzelfde
# wensen
# denken
# oud
# koppelen
# voordeel
# zoek
# eer
# s20
# verreken
# aankoop
# mb.s
# bevestigen
# vergissing
# opnemen
# overleg
# I
# daglimiet
# heen
# provisor
# abbononent
# Sardinië
# maximaal
# weten
# man
# vernieuwen
# Simyo
# gb's
# paket
# wi-fi
# ïnstalleeren
# beschrijven
# mobiel
# voorgaan
# beschikbaar
# goed
# tenaamstelling
# eenmanszaak
# plaatsen
# aansluitkosten
# ruim
# paardag
# ipv
# facuutr
# verhoog
# abbo
# 2euro
# mi
# hulp
# beller
# is,30
# beslist
# verleng
# all
# mobiel_telefoonnummer
# mand
# kr
# abo
# vanmiddag
# kunnen
# aangekochte
# hallo
# icloud
# helemaal
# vol
# koop
# telkens
# contorat
# internetthuis
# probleem
# inzien
# goedemidsag
# installatiemonteur
# rondgemaskt
# geacht
# heer/mevrouw
# duidelijk
# aangeven
# late
# mobil
# steed
#
#
# Aanpas
# plus
# terugbellen
# i.c.m
# werken
# bestaand
# contractduur
# Mobiel
# regel
# combinatie
# simonly
# corrigeren
# september
# minimum
# nee
# ideal
# lijn
# blokkeren
# waardeloos
# 👎
# 🏻
# my-tmobile
# oplossen
# 4_g
# quota
# perse
# daarvan
# lotte
# overstappen
# abb
# overzetten
# +
# nirts
# horen
# mujn
# starten
# automatisch
# overzicht
# activiren
# gigabytes
# verdwan
# mailadre
# vm
# gebruikskost
# abon
# moment
# goedemorg
# diet
# app
# kijk
# hok
# ingeschakeld
# installatie
# supersnel
# verwerken
# klantenvoordeel
# internetsnelheid
# gewoon
# aanbieding
# inlog
# wanner
# kwijt
# verander
# Thuis
# opzetten
# mobile
# abonnemet
# b.v.d
# Peter
# kopen
# rood
# lamp
# Brandeni
# partner
# aansluiten
# vactuur
# bespreken
# nadenken
# vastzit
# klantvoordeel
# vervallen
#
# Topic 7:
# abonnement
# factuur
# via
# mail
# krijgen
# keer
# laat
# per
# sturen
# betalen
#
# email
# ontvangen
# staan
# graag
# facturen
# e-mail
# goedemiddag
# factur
# willen
# post
# voortaan
# Mail
# aangeven
# automatisch
# inzien
# komen
# proberen
# adres
# thuis
# hoi
# goed
# ipv
# zojuist
# my
# tmobile
# lotte
# t-mobile
# opvragen
# incasso
# t
# mobile
# vinden
# klant
# koppelen
#
#
#
# zetten
# telefoonnummer
# log
# contract
# nieuw
# bericht
# account
# gegeven
# veranderen
# schrok
# wild
# app
# betaling
# abonnemenen
# faktuur
# kunnen
# slecht
# zakelijk
# prepaid
# locatie
# aansluiting
# datum
# man
# internetverbinding
# betaaldatum
# box
# g
# wijzigen
# e
#
# nergens
# link
# lukken
# constant
# loggen
# maandelijks
# kiezen
# gaan
# informatie
# Mobiel
# overstap
# doorgeven
# mailadres
# goedemorg
# glasvezel
# ergens
# december
# medewerker
# 2x
# geverifieer
# verzend
# verleng
# belsimpel
# kloppen
# thuisadres
# stopcontact
# Sales
# number
# sorry
# mis
#
# zien
# heden
# ontvang
# zoek
# pin/ideal
# pinpas
# activeringskost
# erg
# waarderen
# e-maild
# zeggen
# terug
# vestiging
# internet
# julie
# mailen
# werk
# e-sim
# nemen
# laasat
# sim
# pff
# waarvan
# sms
# degelijk
# geld
# rekening
# contact
# conformeur
# bel
# wacht
# bestellen
# a
# helemaal
# werken
# verificatiecood
# maandfactuur
# klpen
# juist
# vi
# goedemorgen
# kenmerk
# laastergen
# april
# aantal
# melden
# hooi
# aub
# abonnementsfacturen
# plaats
# brief
# pdf
# vragen
# uitstellen
# blijven
# betaalgegeven
# Staa
# eind
# vast
# mailtje
# kijken
# vrijdag
# telefoon
# opgehalen
# plekk
# inlog-email
# mening
# instellen
# snap
# sta
# blokkeren
# benieuwd
# verwachten
# hi
# eenmalig
# beltegoed
# laten
# verrekenen
#
#
# bedanken
# bijlage
# mn
# controleerbaar
# stopzetten
# ontvangne
# zenden
# maand
# open
# vraag
# verzonden
# verkeerd
# noteren
# opzegging
# regelen
# kpn
# numm
# uitgevallen
# grrag
# ideal
# voot
# verschillend
# tijd
# Ingelogd
# succes
# zoekgeraakken
# emailadres
# daaar
# inlog
# binnenkort
# grap
# ík
# handig
# pc
# melding
# trouwens
# een
# Klaarstaat
# kannniks
# samsung
# s10
# plus
# aanschaf
# notificatie
# tahiti
# beschikbaar
# deben
# Hallo
# direct
# boekhoudpakket
# oer
#
# Topic 8:
# abonnemenen
# g
# abonnement
# thuis
# maandelijks
# opzegbaar
# internet
# lopen
# maand
# worden
# goedemiddag
# abbonement
# wifi
# verlengen
# abbonnement
# videoland
# vraag
# nemen
# contract
# hoi
# jaar
# abonoment
# staan
# simonly
# weten
# only
# sim
# automatisch
# hi
# opzegg
# graag
# vast
# willen
# tmobile
# kunnen
# tv
# bundel
# opzeggen
# goed
# bieden
# telefoon
# wijzigen
# verleng
# maandelijk
# blijken
# verbruik
# pakket
# dataverbruik
# verlagen
# looptijd
# dag
# modem
# t
# mobile
# denken
# veranderen
# nummer
# klant
# goedkoop
# wijzig
# hey
#
#
# toevoegen
# middag
# Aanpassen
# will
# opzeg
# betaal
# afsluiten
# mandelijks
# ozegbaar
# activeren
# inschakelen
# tablet
# huidig
# versterker
# verloop
# datum
# hoelang
# termijnbedrag
# begrijpen
# naam
# waaronder
# eindigen
# downgraden
# ophogen
# loten
# thuisabbonement
# esr
# aangemeld
# stellen
# plaats
# goedemorgewn
# doorlopen
# vernieuwen
# voo
# 2jarig
# 27-9
# gister
# gaan
# helaas
# niks
# vernemen
# toestelbetaling
# zaak
# binnekort
# ma
# stopzetten
# medeweten
# hand
# huawai
# zeggen
# verbending
# wienig
# maandlijk
# paar
# omzetten
# combi
# bundels
# interactief
# ongebruikt
# kast
# terugsturen
# hoeveel
# geheel
# simkaart
# stopzeggen
#
# esimkost
# eenmalig
# mifi
# vehoog
# plan
# doorgijven
# wekelijks
# goedendag
# tijd
# anbeperkt
# data
# perongeluk
# ipv
# I
# veilig
# bescherming
# sim-only
# zoek
# datagebruik
# lotte
# zondag
# vragen
# baar
# wil/moeten
# maat
# zien
# zitten
# bijstellen
# overzetten/verlengen
# vrouw
# mjjn
# abonnnent
# overstap
# maandelijkb
# abbonoment
# afsluit
# mee
# korting
# onlangs
# box
# opzegging
# actief
# overzicht
# Mocro
# maffia
# informatie
# tussentijds
# v/h
# gereset
# aansluiten
# jarig
# travel
# surf
# aanvragen
# vandaar
# aanvraag
# zoeken
# lk
# internetbakket
# mijn
# signaal
# behoud
# toepassen
# terms
# and
# condition
# minimum
# telefoonkrediet
# weren
# Mobiel
# voordeliger
# abonnemnet
# porter
# geslacht
# betaallink
# aangevraagd
# toestel
# erbij
# afgeschreven
# stopzett
# unlimited
# uitzetten
# goedemorgen
# detail
# dagelijks
# internetverbruik
#
# Topic 9:
# graag
# wijzig
# per
# locatie
# hoi
# worden
# dag
# bellen
# nummer
# gaan
# willen
# buitenlands
# week
# lastig
# vallen
# onbekend
# telefoonnummer
# buitenland
# goedemiddag
# gebeld
# mens
# 5x
# allerlei
# heel
# bereikbaar
# persoon
# goedenavond
# oproep
# vraag
# appten
# keer
# blokkeren
# opnemen
# terug
# land
# weten
# goedemorgen
# tijdelijk
# zojuist
# ongeluk
# Hallo
# vrouw
# vreemd
# internet
# lotte
# betalingsregeling
#
#
#
# etnische_groep
# kost
# jaar
# nieuw
# werk
# overgezet
# verschillend
# verkoop
# 1x
# afschrijven
# blijven
# zeggen
# n
# band
# t-mobile
# beweren
# probleem
# nodig
# waarbij
# echt
# telefonisch
# vandaag
# laat
# Blokkeer
# rekening
# bereik
# komen
# vakantie
# volgen
# datum
# hallo
# paar
# verbinden
# ophangen
# missen
#
#
# niks
# telefoonnr
# zitten
# moment
# westkust
# werknemer
# shop
# geven
# bedrag
# mn
# man
# grmiddeld
# grbeld
# achterstalling
# automatisch
# afgespeeld
# groot
# ieder
# c
# houd
# terugbellen
# fraud
# afvragen
# Corona
# heen
# engels
# telefoon
# lastiggevallen
# achterhalen
# chromecast
# beller
# ’n
# tmobile
# klpen
# frauduleus
# reageren
# Mobiel
# bestaan
# uitgelekken
# samsung
# a72
# oplichter
# ditmaal
# vinden
# fijn
# treffen
# half
# abonnoment
# overgezetten
# werken
# opbellen
# extra
# krijgen
# ongewenste
# super
# soms
# onmiddellijk
# lotten
# meermaals
# dagelijks
# bericht
# programma
# 070-2085350
# verlenging
# abonn
# pagina
# overgestapt
# proberen
# vertellen
# toestemming
# directeur
# interview
# houden
# achteraf
# kloppen
# abonnement
# my
# afspreken
# oplichten
# steffie
# gooien
# internetbooster
# zolder
# schijn
# volkomen
# scammen
# hieraan
# dom
# tebgef
# oproepen
# doen
# Nederlands
# bitcoin
# firma
# iban
# intimidatie
# doof
# duur
# broek
# nemen
# schijt
# provider
# s
# avond
# zodat
# telefoonnummeren
# and
# stuuren
# ideal
# gm
# aantal
# nogmaals
# spreken
# schijnen
# /22
# Geneldte
# totaal
# toenet
# raar
# bekend
# scamen
# scammer
# niemand
# +44
# continu
# reden
# bedrijf
# vanmorgen
# blijken
# inleveren
# apparatuur
# activeren
# t-mobiles
# behoefte
# scam
# nationaliteit
# wonen
# abonneren
# document
# tv
# Srry
# verificatiecode
# ongeldig
#
# veel
# 10-plus
# Jull
# vragen
# privé
# doorgaan
# online
# aanvragen
# betaallink
# behouden
# curaçao
# Europees
# unie
# teruggebled
# gewoon
# mobiel
# kennen
# aangevraagd
# continue
# will
# an
# schriken
# rot
# vd
# verlengen
# geld
# herkennen

# %% [markdown]
# #### LDA
# Now lets try LDA itself

# %%
Lda = gensim.models.ldamodel.LdaModel

def extract_topic(corpus, num_topics=10, n_words=10):
    
    clean_corpus=corpus.str.split(' ').tolist()
    
    dict_ = corpora.Dictionary(clean_corpus)
    
    doc_term_matrix = [dict_.doc2bow(i) for i in clean_corpus]

    ldamodel = Lda(doc_term_matrix, num_topics=num_topics, id2word = dict_, passes=1, random_state=0, eval_every=None,iterations=100)

    return ldamodel,ldamodel.print_topics(num_topics=num_topics, num_words=n_words),ldamodel.show_topics(formatted=False),doc_term_matrix

def cloud_generate(topics,size=5):
    
    cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

    cloud = WordCloud(stopwords=dutch_stop_words,
                      background_color='white',
                      width=2500,
                      height=1800,
                      max_words=10,
                      colormap='tab10',
                      color_func=lambda *args, **kwargs: cols[i],
                      prefer_horizontal=1.0)

    fig, axes = plt.subplots(2,size, figsize=(10,10), sharex=True, sharey=True)

    for i, ax in enumerate(axes.flatten()):
        fig.add_subplot(ax)
        topic_words = dict(topics[i][1])
        cloud.generate_from_frequencies(topic_words, max_font_size=300)
        plt.gca().imshow(cloud)
        plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
        plt.gca().axis('off')


    plt.subplots_adjust(wspace=0, hspace=0)
    plt.axis('off')
    plt.margins(x=0, y=0)
    plt.tight_layout()
    plt.show()

# %%
ldamodel,show_topics,topics, corpus=extract_topic(cleaned_test_df['cleaned_text'],25,10)

# %%
print(show_topics)
# Out:
# [(0, '0.137*"abonnemenen" + 0.120*"wijzig" + 0.041*"aanpassen" + 0.032*"staan" + 0.026*"factuur" + 0.025*"internet" + 0.022*"laat" + 0.021*"activeren" + 0.019*"abonnement" + 0.018*"app"'), (1, '0.047*"graag" + 0.043*"betalen" + 0.042*"internet" + 0.041*"thuis" + 0.037*"abonnemenen" + 0.034*"wifi" + 0.032*"ideal" + 0.028*"g" + 0.024*"factuur" + 0.024*"link"'), (2, '0.254*"g" + 0.167*"thuis" + 0.025*"nummer" + 0.024*"abonnemenen" + 0.017*"internet" + 0.015*"locatie" + 0.015*"vraag" + 0.011*"krijgen" + 0.011*"t" + 0.011*"extra"'), (3, '0.082*"activeren" + 0.037*"abonnement" + 0.034*"krijgen" + 0.031*"gb" + 0.022*"sms" + 0.020*"geven" + 0.018*"netwerk" + 0.017*"per" + 0.016*"abonnemenen" + 0.016*"beschikbaar"'), (4, '0.075*"factuur" + 0.069*"ideal" + 0.043*"link" + 0.043*"betalen" + 0.042*"abonnemenen" + 0.035*"verbinding" + 0.035*"sturen" + 0.030*"wijzig" + 0.023*"via" + 0.023*"nieuw"'), (5, '0.048*"nummer" + 0.041*"laat" + 0.036*"ideal" + 0.035*"account" + 0.033*"bellen" + 0.032*"rekening" + 0.029*"factuur" + 0.025*"verbinding" + 0.024*"onbekend" + 0.020*"geven"'), (6, '0.077*"bellen" + 0.075*"worden" + 0.029*"nummer" + 0.028*"e-mail" + 0.028*"factuur" + 0.024*"telefoonnummer" + 0.018*"ontvangen" + 0.018*"graag" + 0.017*"krijgen" + 0.016*"huidig"'), (7, '0.085*"graag" + 0.074*"factuur" + 0.043*"kloppen" + 0.033*"afbetaling" + 0.031*"mail" + 0.030*"factur" + 0.030*"krijgen" + 0.029*"telefoon" + 0.026*"ontvangen" + 0.024*"laat"'), (8, '0.069*"beschikbaar" + 0.061*"pro" + 0.051*"iphone" + 0.035*"max" + 0.034*"afbetalen" + 0.033*"abonnemenen" + 0.027*"telefoon" + 0.027*"hoi" + 0.025*"g" + 0.025*"graag"'), (9, '0.122*"abonnemenen" + 0.060*"traag" + 0.059*"activeren" + 0.049*"internet" + 0.040*"wijzig" + 0.037*"g" + 0.026*"per" + 0.018*"graag" + 0.017*"service" + 0.017*"vandaag"'), (10, '0.091*"bellen" + 0.083*"bereik" + 0.056*"slecht" + 0.044*"extra" + 0.041*"kopen" + 0.034*"\n" + 0.032*"locatie" + 0.031*"worden" + 0.027*"nummer" + 0.025*"mb"'), (11, '0.095*"internet" + 0.090*"locatie" + 0.050*"bundel" + 0.041*"toestel" + 0.023*"mb" + 0.020*"verhogen" + 0.020*"iphone" + 0.019*"afbetelen" + 0.018*"aflossen" + 0.017*"gebruiken"'), (12, '0.072*"factuur" + 0.048*"netwerk" + 0.029*"abonnement" + 0.028*"via" + 0.024*"krijgen" + 0.021*"abbonement" + 0.021*"graag" + 0.021*"veranderen" + 0.019*"internet" + 0.018*"laat"'), (13, '0.063*"factuur" + 0.044*"afbetalen" + 0.040*"laat" + 0.039*"activeren" + 0.029*"deezer" + 0.029*"\n" + 0.029*"toestelkrediet" + 0.020*"graag" + 0.018*"extra" + 0.018*"keer"'), (14, '0.094*"telefoon" + 0.054*"betalen" + 0.031*"service" + 0.024*"nieuw" + 0.022*"zien" + 0.020*"factuur" + 0.020*"deezer" + 0.020*"krijgen" + 0.016*"" + 0.016*"betaling"'), (15, '0.082*"buitenland" + 0.062*"g" + 0.037*"thuis" + 0.030*"€" + 0.023*"maandelijks" + 0.020*"abonnement" + 0.018*"automatisch" + 0.017*"betalen" + 0.016*"toestelkrediet" + 0.016*"zitten"'), (16, '0.053*"gb" + 0.046*"g" + 0.045*"vallen" + 0.038*"werken" + 0.030*"doen" + 0.025*"nummer" + 0.025*"verkopen" + 0.021*"" + 0.019*"lastig" + 0.019*"klpen"'), (17, '0.081*"betalen" + 0.038*"bedrag" + 0.037*"factuur" + 0.028*"graag" + 0.027*"ideal" + 0.024*"staan" + 0.021*"abonnement" + 0.020*"openstaan" + 0.020*"via" + 0.019*"komen"'), (18, '0.076*"locatie" + 0.051*"abonnemenen" + 0.040*"wijzig" + 0.039*"g" + 0.026*"abonnement" + 0.024*"activeren" + 0.017*"ontvang" + 0.014*"slecht" + 0.014*"unlimited" + 0.013*"maandelijks"'), (19, '0.097*"factuur" + 0.049*"locatie" + 0.040*"mb" + 0.028*"email" + 0.027*"ontvangen" + 0.025*"buitenland" + 0.022*"per" + 0.021*"dagelijks" + 0.020*"bellen" + 0.017*"laat"'), (20, '0.047*"gebruiken" + 0.030*"abonnemenen" + 0.026*"kost" + 0.026*"locatie" + 0.025*"gratis" + 0.022*"internet" + 0.021*"extra" + 0.020*"telefoon" + 0.020*"\n" + 0.019*"rekening"'), (21, '0.210*"locatie" + 0.041*"telefoonnummer" + 0.034*"factuur" + 0.024*"datum" + 0.023*"link" + 0.023*"Mobiel" + 0.021*"bellen" + 0.019*"staan" + 0.018*"service" + 0.017*"kijken"'), (22, '0.211*"" + 0. ...

# %%
topics
# Out:
# [(13,
#   [('factuur', 0.06294772),
#    ('afbetalen', 0.04414381),
#    ('laat', 0.039929796),
#    ('activeren', 0.038840424),
#    ('deezer', 0.029068412),
#    ('\n', 0.028835662),
#    ('toestelkrediet', 0.028588157),
#    ('graag', 0.01982737),
#    ('extra', 0.017631622),
#    ('keer', 0.017594466)]),
#  (11,
#   [('internet', 0.09530639),
#    ('locatie', 0.08968945),
#    ('bundel', 0.050451055),
#    ('toestel', 0.040639922),
#    ('mb', 0.022601888),
#    ('verhogen', 0.019520653),
#    ('iphone', 0.019510698),
#    ('afbetelen', 0.019173242),
#    ('aflossen', 0.017753042),
#    ('gebruiken', 0.016827421)]),
#  (4,
#   [('factuur', 0.07514506),
#    ('ideal', 0.06940462),
#    ('link', 0.042815235),
#    ('betalen', 0.04280702),
#    ('abonnemenen', 0.04245677),
#    ('verbinding', 0.03547632),
#    ('sturen', 0.035296768),
#    ('wijzig', 0.029542074),
#    ('via', 0.023364438),
#    ('nieuw', 0.022786384)]),
#  (12,
#   [('factuur', 0.0717208),
#    ('netwerk', 0.04756687),
#    ('abonnement', 0.02862928),
#    ('via', 0.028044993),
#    ('krijgen', 0.024288876),
#    ('abbonement', 0.02142794),
#    ('graag', 0.021171533),
#    ('veranderen', 0.020658989),
#    ('internet', 0.018590689),
#    ('laat', 0.01837957)]),
#  (17,
#   [('betalen', 0.08075715),
#    ('bedrag', 0.03835007),
#    ('factuur', 0.037124984),
#    ('graag', 0.02811684),
#    ('ideal', 0.026818173),
#    ('staan', 0.024129486),
#    ('abonnement', 0.020816544),
#    ('openstaan', 0.019992702),
#    ('via', 0.019569455),
#    ('komen', 0.018500997)]),
#  (5,
#   [('nummer', 0.047614407),
#    ('laat', 0.041158672),
#    ('ideal', 0.03631419),
#    ('account', 0.035222497),
#    ('bellen', 0.032994233),
#    ('rekening', 0.031540528),
#    ('factuur', 0.028959122),
#    ('verbinding', 0.024837643),
#    ('onbekend', 0.023547452),
#    ('geven', 0.020067554)]),
#  (15,
#   [('buitenland', 0.08228753),
#    ('g', 0.062137246),
#    ('thuis', 0.036998294),
#    ('€', 0.030083949),
#    ('maandelijks', 0.022627367),
#    ('abonnement', 0.020421997),
#    ('automatisch', 0.017970113),
#    ('betalen', 0.017297884),
#    ('toestelkrediet', 0.016330663),
#    ('zitten', 0.015708668)]),
#  (3,
#   [('activeren', 0.08212075),
#    ('abonnement', 0.036831696),
#    ('krijgen', 0.03375654),
#    ('gb', 0.030514939),
#    ('sms', 0.02239558),
#    ('geven', 0.019945536),
#    ('netwerk', 0.01822729),
#    ('per', 0.01733956),
#    ('abonnemenen', 0.016376343),
#    ('beschikbaar', 0.01633885)]),
#  (16,
#   [('gb', 0.052707873),
#    ('g', 0.04602047),
#    ('vallen', 0.04464337),
#    ('werken', 0.037951343),
#    ('doen', 0.030239873),
#    ('nummer', 0.02542598),
#    ('verkopen', 0.024638401),
#    ('', 0.020544594),
#    ('lastig', 0.019463625),
#    ('klpen', 0.019034883)]),
#  (18,
#   [('locatie', 0.07585453),
#    ('abonnemenen', 0.050779488),
#    ('wijzig', 0.040399894),
#    ('g', 0.039217837),
#    ('abonnement', 0.026389103),
#    ('activeren', 0.024452519),
#    ('ontvang', 0.017362302),
#    ('slecht', 0.014412731),
#    ('unlimited', 0.013523684),
#    ('maandelijks', 0.013261285)])]
